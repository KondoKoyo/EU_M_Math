# %% [markdown]
# <a href="https://colab.research.google.com/github/KondoKoyo/EU_M_Math/blob/main/Chap02_Cm_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt
import matplotlib as mp1
import seaborn as sns
import math
# %matplotlib inline

X = np.random.uniform(0.0 , 1.0 , 10000 )
Y = np.random.uniform(0.0 , 1.0 , 10000 )

in_X = []
in_Y = []
out_X = []
out_Y = []

b=0
for i in range(0,10000):
  a = math.hypot( X[i] , Y[i] )
  if a < 1:
    in_X.append(X[i])
    in_Y.append(Y[i])
    b +=1
  else:
    out_X.append(X[i])
    out_Y.append(Y[i])


print(b)

plt.figure(figsize=(6,6))

circle_X = np.arange(0,1,0.001)
circle_Y = np.sqrt(1-circle_X*circle_X)

plt.plot(circle_X,circle_Y)
plt.scatter(in_X,in_Y,color="r")
plt.scatter(out_X,out_Y,color="b")


print("円周率=",4.0*b/10000)
# Out:
# 7891
# 円周率= 3.1564
